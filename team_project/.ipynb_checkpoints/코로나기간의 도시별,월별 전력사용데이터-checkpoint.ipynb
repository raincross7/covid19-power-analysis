# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import pymysql

warnings.filterwarnings('ignore')
plt.rcParams['font.family'] = 'Gulim'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.dpi'] = 100

# %%
# https://home.kepco.co.kr/kepco/KO/ntcob/list.do?boardCd=BRD_000097&menuCd=FN05030101
# 월별 전력 판매량 2020년
판매2001 = pd.read_excel('datas/2020_01_th.xlsx')
판매2002 = pd.read_excel('datas/2020_02_th.xlsx')
판매2003 = pd.read_excel('datas/2020_03_th.xlsx')
판매2004 = pd.read_excel('datas/2020_04_th.xlsx')
판매2005 = pd.read_excel('datas/2020_05_th.xlsx')
판매2006 = pd.read_excel('datas/2020_06_th.xlsx')
판매2007 = pd.read_excel('datas/2020_07_th.xlsx')
판매2008 = pd.read_excel('datas/2020_08_th.xlsx')
판매2009 = pd.read_excel('datas/2020_09_th.xlsx')
판매2010 = pd.read_excel('datas/2020_10_th.xlsx')
판매2011 = pd.read_excel('datas/2020_11_th.xlsx')
판매2012 = pd.read_excel('datas/2020_12_th.xlsx')
# 월별 전력 판매량 2021년
판매2101 = pd.read_excel('datas/2021_01_th.xlsx')
판매2102 = pd.read_excel('datas/2021_02_th.xlsx')
판매2103 = pd.read_excel('datas/2021_03_th.xlsx')
판매2104 = pd.read_excel('datas/2021_04_th.xlsx')
판매2105 = pd.read_excel('datas/2021_05_th.xlsx')
판매2106 = pd.read_excel('datas/2021_06_th.xlsx')
판매2107 = pd.read_excel('datas/2021_07_th.xlsx')
판매2108 = pd.read_excel('datas/2021_08_th.xlsx')
판매2109 = pd.read_excel('datas/2021_09_th.xlsx')
판매2110 = pd.read_excel('datas/2021_10_th.xlsx')
판매2111 = pd.read_excel('datas/2021_11_th.xlsx')
판매2112 = pd.read_excel('datas/2021_12_th.xlsx')
# 월별 전력 판매량 2022년
판매2201 = pd.read_excel('datas/2022_01_th.xlsx')
판매2202 = pd.read_excel('datas/2022_02_th.xlsx')
판매2203 = pd.read_excel('datas/2022_03_th.xlsx')
판매2204 = pd.read_excel('datas/2022_04_th.xlsx')
판매2205 = pd.read_excel('datas/2022_05_th.xlsx')
판매2206 = pd.read_excel('datas/2022_06_th.xlsx')
판매2207 = pd.read_excel('datas/2022_07_th.xlsx')
판매2208 = pd.read_excel('datas/2022_08_th.xlsx')
판매2209 = pd.read_excel('datas/2022_09_th.xlsx')
판매2210 = pd.read_excel('datas/2022_10_th.xlsx')
판매2211 = pd.read_excel('datas/2022_11_th.xlsx')
판매2212 = pd.read_excel('datas/2022_12_th.xlsx')

# %%
# 20년도 정제1
판매2001 = 판매2001.loc[(판매2001.index == 0) | (판매2001.index == 7) | (판매2001.index == 40)]
판매2001 = 판매2001.iloc[:,3:20]
판매2001.index = (['가정용','업무용','산업용'])
판매2001 = 판매2001.astype(int)
판매2001 = 판매2001.T
판매2002 = 판매2002.loc[(판매2002.index == 0) | (판매2002.index == 7) | (판매2002.index == 40)]
판매2002 = 판매2002.iloc[:,3:20]
판매2002.index = (['가정용','업무용','산업용'])
판매2002 = 판매2002.astype(int)
판매2002 = 판매2002.T
판매2003 = 판매2003.loc[(판매2003.index == 0) | (판매2003.index == 7) | (판매2003.index == 40)]
판매2003 = 판매2003.iloc[:,3:20]
판매2003.index = (['가정용','업무용','산업용'])
판매2003 = 판매2003.astype(int)
판매2003 = 판매2003.T
판매2004 = 판매2004.loc[(판매2004.index == 0) | (판매2004.index == 7) | (판매2004.index == 40)]
판매2004 = 판매2004.iloc[:,3:20]
판매2004.index = (['가정용','업무용','산업용'])
판매2004 = 판매2004.astype(int)
판매2004 = 판매2004.T
판매2005 = 판매2005.loc[(판매2005.index == 0) | (판매2005.index == 7) | (판매2005.index == 40)]
판매2005 = 판매2005.iloc[:,3:20]
판매2005.index = (['가정용','업무용','산업용'])
판매2005 = 판매2005.astype(int)
판매2005 = 판매2005.T
판매2006 = 판매2006.loc[(판매2006.index == 0) | (판매2006.index == 7) | (판매2006.index == 40)]
판매2006 = 판매2006.iloc[:,3:20]
판매2006.index = (['가정용','업무용','산업용'])
판매2006 = 판매2006.astype(int)
판매2006 = 판매2006.T
판매2007 = 판매2007.loc[(판매2007.index == 0) | (판매2007.index == 7) | (판매2007.index == 40)]
판매2007 = 판매2007.iloc[:,3:20]
판매2007.index = (['가정용','업무용','산업용'])
판매2007 = 판매2007.astype(int)
판매2007 = 판매2007.T
판매2008 = 판매2008.loc[(판매2008.index == 0) | (판매2008.index == 7) | (판매2008.index == 40)]
판매2008 = 판매2008.iloc[:,3:20]
판매2008.index = (['가정용','업무용','산업용'])
판매2008 = 판매2008.astype(int)
판매2008 = 판매2008.T
판매2009 = 판매2009.loc[(판매2009.index == 0) | (판매2009.index == 7) | (판매2009.index == 40)]
판매2009 = 판매2009.iloc[:,3:20]
판매2009.index = (['가정용','업무용','산업용'])
판매2009 = 판매2009.astype(int)
판매2009 = 판매2009.T
판매2010 = 판매2010.loc[(판매2010.index == 0) | (판매2010.index == 7) | (판매2010.index == 40)]
판매2010 = 판매2010.iloc[:,3:20]
판매2010.index = (['가정용','업무용','산업용'])
판매2010 = 판매2010.astype(int)
판매2010 = 판매2010.T
판매2011 = 판매2011.loc[(판매2011.index == 0) | (판매2011.index == 7) | (판매2011.index == 40)]
판매2011 = 판매2011.iloc[:,3:20]
판매2011.index = (['가정용','업무용','산업용'])
판매2011 = 판매2011.astype(int)
판매2011 = 판매2011.T
판매2012 = 판매2012.loc[(판매2012.index == 0) | (판매2012.index == 7) | (판매2012.index == 40)]
판매2012 = 판매2012.iloc[:,3:20]
판매2012.index = (['가정용','업무용','산업용'])
판매2012 = 판매2012.astype(int)
판매2012 = 판매2012.T
# 21년도 정제1
판매2101 = 판매2101.loc[(판매2101.index == 0) | (판매2101.index == 7) | (판매2101.index == 40)]
판매2101 = 판매2101.iloc[:,3:20]
판매2101.index = (['가정용','업무용','산업용'])
판매2101 = 판매2101.astype(int)
판매2101 = 판매2101.T
판매2102 = 판매2102.loc[(판매2102.index == 0) | (판매2102.index == 7) | (판매2102.index == 40)]
판매2102 = 판매2102.iloc[:,3:20]
판매2102.index = (['가정용','업무용','산업용'])
판매2102 = 판매2102.astype(int)
판매2102 = 판매2102.T
판매2103 = 판매2103.loc[(판매2103.index == 0) | (판매2103.index == 7) | (판매2103.index == 40)]
판매2103 = 판매2103.iloc[:,3:20]
판매2103.index = (['가정용','업무용','산업용'])
판매2103 = 판매2103.astype(int)
판매2103 = 판매2103.T
tmp1 = pd.DataFrame(판매2104.iloc[0].drop([판매2104.columns[0],판매2104.columns[1]])).T
tmp2 = pd.DataFrame(판매2104.iloc[1:3].drop([판매2104.columns[0],판매2104.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2104.iloc[3:6].drop([판매2104.columns[0],판매2104.columns[1]],axis=1).sum()).T
판매2104 = pd.concat([tmp1,tmp2,tmp3])
판매2104 = 판매2104.iloc[:,:17]
판매2104.index = (['가정용','업무용','산업용'])
판매2104 = 판매2104.astype(int)
판매2104 = 판매2104.T
tmp1 = pd.DataFrame(판매2105.iloc[0].drop([판매2105.columns[0],판매2105.columns[1]])).T
tmp2 = pd.DataFrame(판매2105.iloc[1:3].drop([판매2105.columns[0],판매2105.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2105.iloc[3:6].drop([판매2105.columns[0],판매2105.columns[1]],axis=1).sum()).T
판매2105 = pd.concat([tmp1,tmp2,tmp3])
판매2105 = 판매2105.iloc[:,:17]
판매2105.index = (['가정용','업무용','산업용'])
판매2105 = 판매2105.astype(int)
판매2105 = 판매2105.T
tmp1 = pd.DataFrame(판매2106.iloc[0].drop([판매2106.columns[0],판매2106.columns[1]])).T
tmp2 = pd.DataFrame(판매2106.iloc[1:3].drop([판매2106.columns[0],판매2106.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2106.iloc[3:6].drop([판매2106.columns[0],판매2106.columns[1]],axis=1).sum()).T
판매2106 = pd.concat([tmp1,tmp2,tmp3])
판매2106 = 판매2106.iloc[:,:17]
판매2106.index = (['가정용','업무용','산업용'])
판매2106 = 판매2106.astype(int)
판매2106 = 판매2106.T
tmp1 = pd.DataFrame(판매2107.iloc[0].drop([판매2107.columns[0],판매2107.columns[1]])).T
tmp2 = pd.DataFrame(판매2107.iloc[1:3].drop([판매2107.columns[0],판매2107.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2107.iloc[3:6].drop([판매2107.columns[0],판매2107.columns[1]],axis=1).sum()).T
판매2107 = pd.concat([tmp1,tmp2,tmp3])
판매2107 = 판매2107.iloc[:,:17]
판매2107.index = (['가정용','업무용','산업용'])
판매2107 = 판매2107.astype(int)
판매2107 = 판매2107.T
tmp1 = pd.DataFrame(판매2108.iloc[0].drop([판매2108.columns[0],판매2108.columns[1]])).T
tmp2 = pd.DataFrame(판매2108.iloc[1:3].drop([판매2108.columns[0],판매2108.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2108.iloc[3:6].drop([판매2108.columns[0],판매2108.columns[1]],axis=1).sum()).T
판매2108 = pd.concat([tmp1,tmp2,tmp3])
판매2108 = 판매2108.iloc[:,:17]
판매2108.index = (['가정용','업무용','산업용'])
판매2108 = 판매2108.astype(int)
판매2108 = 판매2108.T
tmp1 = pd.DataFrame(판매2109.iloc[0].drop([판매2109.columns[0],판매2109.columns[1]])).T
tmp2 = pd.DataFrame(판매2109.iloc[1:3].drop([판매2109.columns[0],판매2109.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2109.iloc[3:6].drop([판매2109.columns[0],판매2109.columns[1]],axis=1).sum()).T
판매2109 = pd.concat([tmp1,tmp2,tmp3])
판매2109 = 판매2109.iloc[:,:17]
판매2109.index = (['가정용','업무용','산업용'])
판매2109 = 판매2109.astype(int)
판매2109 = 판매2109.T
tmp1 = pd.DataFrame(판매2110.iloc[0].drop([판매2110.columns[0],판매2110.columns[1]])).T
tmp2 = pd.DataFrame(판매2110.iloc[1:3].drop([판매2110.columns[0],판매2110.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2110.iloc[3:6].drop([판매2110.columns[0],판매2110.columns[1]],axis=1).sum()).T
판매2110 = pd.concat([tmp1,tmp2,tmp3])
판매2110 = 판매2110.iloc[:,:17]
판매2110.index = (['가정용','업무용','산업용'])
판매2110 = 판매2110.astype(int)
판매2110 = 판매2110.T
tmp1 = pd.DataFrame(판매2111.iloc[0].drop([판매2111.columns[0],판매2111.columns[1]])).T
tmp2 = pd.DataFrame(판매2111.iloc[1:3].drop([판매2111.columns[0],판매2111.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2111.iloc[3:6].drop([판매2111.columns[0],판매2111.columns[1]],axis=1).sum()).T
판매2111 = pd.concat([tmp1,tmp2,tmp3])
판매2111 = 판매2111.iloc[:,:17]
판매2111.index = (['가정용','업무용','산업용'])
판매2111 = 판매2111.astype(int)
판매2111 = 판매2111.T
tmp1 = pd.DataFrame(판매2112.iloc[0].drop([판매2112.columns[0],판매2112.columns[1]])).T
tmp2 = pd.DataFrame(판매2112.iloc[1:3].drop([판매2112.columns[0],판매2112.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2112.iloc[3:6].drop([판매2112.columns[0],판매2112.columns[1]],axis=1).sum()).T
판매2112 = pd.concat([tmp1,tmp2,tmp3])
판매2112 = 판매2112.iloc[:,:17]
판매2112.index = (['가정용','업무용','산업용'])
판매2112 = 판매2112.astype(int)
판매2112 = 판매2112.T
# 22년도 정제1
tmp1 = pd.DataFrame(판매2201.iloc[0].drop([판매2201.columns[0],판매2201.columns[1]])).T
tmp2 = pd.DataFrame(판매2201.iloc[1:3].drop([판매2201.columns[0],판매2201.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2201.iloc[3:6].drop([판매2201.columns[0],판매2201.columns[1]],axis=1).sum()).T
판매2201 = pd.concat([tmp1,tmp2,tmp3])
판매2201 = 판매2201.iloc[:,:17]
판매2201.index = (['가정용','업무용','산업용'])
판매2201 = 판매2201.astype(int)
판매2201 = 판매2201.T
tmp1 = pd.DataFrame(판매2202.iloc[0].drop([판매2202.columns[0],판매2202.columns[1]])).T
tmp2 = pd.DataFrame(판매2202.iloc[1:3].drop([판매2202.columns[0],판매2202.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2202.iloc[3:6].drop([판매2202.columns[0],판매2202.columns[1]],axis=1).sum()).T
판매2202 = pd.concat([tmp1,tmp2,tmp3])
판매2202 = 판매2202.iloc[:,:17]
판매2202.index = (['가정용','업무용','산업용'])
판매2202 = 판매2202.astype(int)
판매2202 = 판매2202.T
tmp1 = pd.DataFrame(판매2203.iloc[0].drop([판매2203.columns[0],판매2203.columns[1]])).T
tmp2 = pd.DataFrame(판매2203.iloc[1:3].drop([판매2203.columns[0],판매2203.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2203.iloc[3:6].drop([판매2203.columns[0],판매2203.columns[1]],axis=1).sum()).T
판매2203 = pd.concat([tmp1,tmp2,tmp3])
판매2203 = 판매2203.iloc[:,:17]
판매2203.index = (['가정용','업무용','산업용'])
판매2203 = 판매2203.astype(int)
판매2203 = 판매2203.T
tmp1 = pd.DataFrame(판매2204.iloc[0].drop([판매2204.columns[0],판매2204.columns[1]])).T
tmp2 = pd.DataFrame(판매2204.iloc[1:3].drop([판매2204.columns[0],판매2204.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2204.iloc[3:6].drop([판매2204.columns[0],판매2204.columns[1]],axis=1).sum()).T
판매2204 = pd.concat([tmp1,tmp2,tmp3])
판매2204 = 판매2204.iloc[:,:17]
판매2204.index = (['가정용','업무용','산업용'])
판매2204 = 판매2204.astype(int)
판매2204 = 판매2204.T
tmp1 = pd.DataFrame(판매2205.iloc[0].drop([판매2205.columns[0],판매2205.columns[1]])).T
tmp2 = pd.DataFrame(판매2205.iloc[1:3].drop([판매2205.columns[0],판매2205.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2205.iloc[3:6].drop([판매2205.columns[0],판매2205.columns[1]],axis=1).sum()).T
판매2205 = pd.concat([tmp1,tmp2,tmp3])
판매2205 = 판매2205.iloc[:,:17]
판매2205.index = (['가정용','업무용','산업용'])
판매2205 = 판매2205.astype(int)
판매2205 = 판매2205.T
tmp1 = pd.DataFrame(판매2206.iloc[0].drop([판매2206.columns[0],판매2206.columns[1]])).T
tmp2 = pd.DataFrame(판매2206.iloc[1:3].drop([판매2206.columns[0],판매2206.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2206.iloc[3:6].drop([판매2206.columns[0],판매2206.columns[1]],axis=1).sum()).T
판매2206 = pd.concat([tmp1,tmp2,tmp3])
판매2206 = 판매2206.iloc[:,:17]
판매2206.index = (['가정용','업무용','산업용'])
판매2206 = 판매2206.astype(int)
판매2206 = 판매2206.T
tmp1 = pd.DataFrame(판매2207.iloc[0].drop([판매2207.columns[0],판매2207.columns[1]])).T
tmp2 = pd.DataFrame(판매2207.iloc[1:3].drop([판매2207.columns[0],판매2207.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2207.iloc[3:6].drop([판매2207.columns[0],판매2207.columns[1]],axis=1).sum()).T
판매2207 = pd.concat([tmp1,tmp2,tmp3])
판매2207 = 판매2207.iloc[:,:17]
판매2207.index = (['가정용','업무용','산업용'])
판매2207 = 판매2207.astype(int)
판매2207 = 판매2207.T
tmp1 = pd.DataFrame(판매2208.iloc[0].drop([판매2208.columns[0],판매2208.columns[1]])).T
tmp2 = pd.DataFrame(판매2208.iloc[1:3].drop([판매2208.columns[0],판매2208.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2208.iloc[3:6].drop([판매2208.columns[0],판매2208.columns[1]],axis=1).sum()).T
판매2208 = pd.concat([tmp1,tmp2,tmp3])
판매2208 = 판매2208.iloc[:,:17]
판매2208.index = (['가정용','업무용','산업용'])
판매2208 = 판매2208.astype(int)
판매2208 = 판매2208.T
tmp1 = pd.DataFrame(판매2209.iloc[0].drop([판매2209.columns[0],판매2209.columns[1]])).T
tmp2 = pd.DataFrame(판매2209.iloc[1:3].drop([판매2209.columns[0],판매2209.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2209.iloc[3:6].drop([판매2209.columns[0],판매2209.columns[1]],axis=1).sum()).T
판매2209 = pd.concat([tmp1,tmp2,tmp3])
판매2209 = 판매2209.iloc[:,:17]
판매2209.index = (['가정용','업무용','산업용'])
판매2209 = 판매2209.astype(int)
판매2209 = 판매2209.T
tmp1 = pd.DataFrame(판매2210.iloc[0].drop([판매2210.columns[0],판매2210.columns[1]])).T
tmp2 = pd.DataFrame(판매2210.iloc[1:3].drop([판매2210.columns[0],판매2210.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2210.iloc[3:6].drop([판매2210.columns[0],판매2210.columns[1]],axis=1).sum()).T
판매2210 = pd.concat([tmp1,tmp2,tmp3])
판매2210 = 판매2210.iloc[:,:17]
판매2210.index = (['가정용','업무용','산업용'])
판매2210 = 판매2210.astype(int)
판매2210 = 판매2210.T
tmp1 = pd.DataFrame(판매2211.iloc[0].drop([판매2211.columns[0],판매2211.columns[1]])).T
tmp2 = pd.DataFrame(판매2211.iloc[1:3].drop([판매2211.columns[0],판매2211.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2211.iloc[3:6].drop([판매2211.columns[0],판매2211.columns[1]],axis=1).sum()).T
판매2211 = pd.concat([tmp1,tmp2,tmp3])
판매2211 = 판매2211.iloc[:,:17]
판매2211.index = (['가정용','업무용','산업용'])
판매2211 = 판매2211.astype(int)
판매2211 = 판매2211.T
tmp1 = pd.DataFrame(판매2212.iloc[0].drop([판매2212.columns[0],판매2212.columns[1]])).T
tmp2 = pd.DataFrame(판매2212.iloc[1:3].drop([판매2212.columns[0],판매2212.columns[1]],axis=1).sum()).T
tmp3 = pd.DataFrame(판매2212.iloc[3:6].drop([판매2212.columns[0],판매2212.columns[1]],axis=1).sum()).T
판매2212 = pd.concat([tmp1,tmp2,tmp3])
판매2212 = 판매2212.iloc[:,:17]
판매2212.index = (['가정용','업무용','산업용'])
판매2212 = 판매2212.astype(int)
판매2212 = 판매2212.T
# 20년도 정제2
판매2001.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2001.reset_index(inplace=True)
판매2001.rename(columns = {'index':'지역'},inplace=True)
판매2001.insert(0,'Month','01')
판매2001.insert(0,'Year','2020')

판매2002.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2002.reset_index(inplace=True)
판매2002.rename(columns = {'index':'지역'},inplace=True)
판매2002.insert(0,'Month','02')
판매2002.insert(0,'Year','2020')

판매2003.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2003.reset_index(inplace=True)
판매2003.rename(columns = {'index':'지역'},inplace=True)
판매2003.insert(0,'Month','03')
판매2003.insert(0,'Year','2020')

판매2004.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2004.reset_index(inplace=True)
판매2004.rename(columns = {'index':'지역'},inplace=True)
판매2004.insert(0,'Month','04')
판매2004.insert(0,'Year','2020')

판매2005.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2005.reset_index(inplace=True)
판매2005.rename(columns = {'index':'지역'},inplace=True)
판매2005.insert(0,'Month','05')
판매2005.insert(0,'Year','2020')

판매2006.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2006.reset_index(inplace=True)
판매2006.rename(columns = {'index':'지역'},inplace=True)
판매2006.insert(0,'Month','06')
판매2006.insert(0,'Year','2020')

판매2007.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2007.reset_index(inplace=True)
판매2007.rename(columns = {'index':'지역'},inplace=True)
판매2007.insert(0,'Month','07')
판매2007.insert(0,'Year','2020')

판매2008.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2008.reset_index(inplace=True)
판매2008.rename(columns = {'index':'지역'},inplace=True)
판매2008.insert(0,'Month','08')
판매2008.insert(0,'Year','2020')

판매2009.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2009.reset_index(inplace=True)
판매2009.rename(columns = {'index':'지역'},inplace=True)
판매2009.insert(0,'Month','09')
판매2009.insert(0,'Year','2020')

판매2010.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2010.reset_index(inplace=True)
판매2010.rename(columns = {'index':'지역'},inplace=True)
판매2010.insert(0,'Month','10')
판매2010.insert(0,'Year','2020')

판매2011.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2011.reset_index(inplace=True)
판매2011.rename(columns = {'index':'지역'},inplace=True)
판매2011.insert(0,'Month','11')
판매2011.insert(0,'Year','2020')

판매2012.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2012.reset_index(inplace=True)
판매2012.rename(columns = {'index':'지역'},inplace=True)
판매2012.insert(0,'Month','12')
판매2012.insert(0,'Year','2020')
# 21년도 정제2
판매2101.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2101.reset_index(inplace=True)
판매2101.rename(columns = {'index':'지역'},inplace=True)
판매2101.insert(0,'Month','01')
판매2101.insert(0,'Year','2021')

판매2102.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2102.reset_index(inplace=True)
판매2102.rename(columns = {'index':'지역'},inplace=True)
판매2102.insert(0,'Month','02')
판매2102.insert(0,'Year','2021')

판매2103.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2103.reset_index(inplace=True)
판매2103.rename(columns = {'index':'지역'},inplace=True)
판매2103.insert(0,'Month','03')
판매2103.insert(0,'Year','2021')

판매2104.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2104.reset_index(inplace=True)
판매2104.rename(columns = {'index':'지역'},inplace=True)
판매2104.insert(0,'Month','04')
판매2104.insert(0,'Year','2021')

판매2105.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2105.reset_index(inplace=True)
판매2105.rename(columns = {'index':'지역'},inplace=True)
판매2105.insert(0,'Month','05')
판매2105.insert(0,'Year','2021')

판매2106.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2106.reset_index(inplace=True)
판매2106.rename(columns = {'index':'지역'},inplace=True)
판매2106.insert(0,'Month','06')
판매2106.insert(0,'Year','2021')

판매2107.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2107.reset_index(inplace=True)
판매2107.rename(columns = {'index':'지역'},inplace=True)
판매2107.insert(0,'Month','07')
판매2107.insert(0,'Year','2021')

판매2108.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2108.reset_index(inplace=True)
판매2108.rename(columns = {'index':'지역'},inplace=True)
판매2108.insert(0,'Month','08')
판매2108.insert(0,'Year','2021')

판매2109.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2109.reset_index(inplace=True)
판매2109.rename(columns = {'index':'지역'},inplace=True)
판매2109.insert(0,'Month','09')
판매2109.insert(0,'Year','2021')

판매2110.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2110.reset_index(inplace=True)
판매2110.rename(columns = {'index':'지역'},inplace=True)
판매2110.insert(0,'Month','10')
판매2110.insert(0,'Year','2021')

판매2111.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2111.reset_index(inplace=True)
판매2111.rename(columns = {'index':'지역'},inplace=True)
판매2111.insert(0,'Month','11')
판매2111.insert(0,'Year','2021')

판매2112.insert(0,'local_id',[11,21,22,23,24,25,26,31,32,33,34,35,36,37,38,39,29])
판매2112.reset_index(inplace=True)
판매2112.rename(columns = {'index':'지역'},inplace=True)
판매2112.insert(0,'Month','12')
판매2112.insert(0,'Year','2021')
# 22년도 정제2
판매2201.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2201.reset_index(inplace=True)
판매2201.rename(columns = {'index':'지역'},inplace=True)
판매2201.insert(0,'Month','01')
판매2201.insert(0,'Year','2022')

판매2202.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2202.reset_index(inplace=True)
판매2202.rename(columns = {'index':'지역'},inplace=True)
판매2202.insert(0,'Month','02')
판매2202.insert(0,'Year','2022')

판매2203.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2203.reset_index(inplace=True)
판매2203.rename(columns = {'index':'지역'},inplace=True)
판매2203.insert(0,'Month','03')
판매2203.insert(0,'Year','2022')

판매2204.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2204.reset_index(inplace=True)
판매2204.rename(columns = {'index':'지역'},inplace=True)
판매2204.insert(0,'Month','04')
판매2204.insert(0,'Year','2022')

판매2205.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2205.reset_index(inplace=True)
판매2205.rename(columns = {'index':'지역'},inplace=True)
판매2205.insert(0,'Month','05')
판매2205.insert(0,'Year','2022')

판매2206.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2206.reset_index(inplace=True)
판매2206.rename(columns = {'index':'지역'},inplace=True)
판매2206.insert(0,'Month','06')
판매2206.insert(0,'Year','2022')

판매2207.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2207.reset_index(inplace=True)
판매2207.rename(columns = {'index':'지역'},inplace=True)
판매2207.insert(0,'Month','07')
판매2207.insert(0,'Year','2022')

판매2208.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2208.reset_index(inplace=True)
판매2208.rename(columns = {'index':'지역'},inplace=True)
판매2208.insert(0,'Month','08')
판매2208.insert(0,'Year','2022')

판매2209.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2209.reset_index(inplace=True)
판매2209.rename(columns = {'index':'지역'},inplace=True)
판매2209.insert(0,'Month','09')
판매2209.insert(0,'Year','2022')

판매2210.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2210.reset_index(inplace=True)
판매2210.rename(columns = {'index':'지역'},inplace=True)
판매2210.insert(0,'Month','10')
판매2210.insert(0,'Year','2022')

판매2211.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2211.reset_index(inplace=True)
판매2211.rename(columns = {'index':'지역'},inplace=True)
판매2211.insert(0,'Month','11')
판매2211.insert(0,'Year','2022')

판매2212.insert(0,'local_id',[11,21,22,23,24,25,26,29,31,32,33,34,35,36,37,38,39])
판매2212.reset_index(inplace=True)
판매2212.rename(columns = {'index':'지역'},inplace=True)
판매2212.insert(0,'Month','12')
판매2212.insert(0,'Year','2022')
# 잘못된 value 변경
판매2101.loc[1,'지역'] = '부  산'
판매2102.loc[1,'지역'] = '부  산'
판매2201.loc[7,'지역'] = '세  종'
# 합치기
판매월별_코로나 = pd.concat([판매2001,판매2002,판매2003,판매2004,판매2005,판매2006,판매2007,판매2008,판매2009,판매2010,판매2011,판매2012,판매2101,판매2102,판매2103,판매2104,판매2105,판매2106,판매2107,판매2108,판매2109,판매2110,판매2111,판매2112,판매2201,판매2202,판매2203,판매2204,판매2205,판매2206,판매2207,판매2208,판매2209,판매2210,판매2211,판매2212])

# %%
판매월별_코로나
# Out:
#     Year Month    지역  local_id      가정용      업무용      산업용
# 0   2020    01  서  울        11  1172543  2881635   142846
# 1   2020    01  부  산        21   409067   821868   601493
# 2   2020    01  대  구        22   285958   598938   476929
# 3   2020    01  인  천        23   363937   807766   936329
# 4   2020    01  광  주        24   179055   352544   224932
# ..   ...   ...   ...       ...      ...      ...      ...
# 12  2022    12  전  북        35   210103   577013  1093903
# 13  2022    12  전  남        36   210855   649969  2108754
# 14  2022    12  경  북        37   306159   986932  2370683
# 15  2022    12  경  남        38   391633   941248  1802069
# 16  2022    12  제  주        39    78040   262398   145783
#
# [612 rows x 7 columns]

# %%
# 총집합 csv파일
판매월별_코로나.to_csv('sale_by_month_covid_th.csv',index=False)
